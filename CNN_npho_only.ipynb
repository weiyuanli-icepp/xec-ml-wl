# %%
import importlib, angle_model_geom
importlib.reload(angle_model_geom)
import importlib, train_angle
importlib.reload(train_angle)
import inspect, angle_model_geom
# print(inspect.getsource(angle_model_geom.HexGraphConv.forward))

# %%
from train_angle import main_angle_with_args
"""
main_angle_with_args(
    root="~/meghome/xec-ml-wl/data/MCGammaAngle_0-49.root",
    tree="tree",
    epochs=50,
    chunksize=16000,
    lr=3e-4,
    amp=True,
    npho_branch="relative_npho",
    NphoScale=2e5,
    max_chunks=None,
    mlflow_experiment="CNN_npho_only",
    run_name="third_try_geometry_modified"
)
"""
main_angle_with_args(
    root="~/meghome/xec-ml-wl/data/MCGammaAngle_0-10.root",
    tree="tree",
    epochs=5,
    batch=2024,
    chunksize=32000,
    lr=3e-4,
    amp=True,
    npho_branch="relative_npho",
    NphoScale=1.0,
    reweight_mode="theta_phi",
    loss_type="smooth_l1",
    outer_mode="finegrid",
    outer_fine_pool=(3,3),
)
# Out:
# [info] using 2D (theta,phi) reweighting
# [001] train 63.201920  val 61.840370  time 20.5s
#    [mem] alloc=0.04 GB, peak=3.07 GB
# [002] train 58.672248  val 55.236569  time 10.9s
#    [mem] alloc=0.04 GB, peak=3.07 GB
# [003] train 52.630071  val 47.892793  time 11.0s
#    [mem] alloc=0.04 GB, peak=3.07 GB
# [004] train 44.225286  val 38.742152  time 10.8s
#    [mem] alloc=0.04 GB, peak=3.07 GB
# [005] train 36.216960  val 35.150082  time 11.0s
#    [mem] alloc=0.04 GB, peak=3.07 GB
# [info] best val_loss = 35.150082
# 2025/11/25 15:07:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/25 15:07:10 WARNING mlflow.models.signature: Failed to infer the model signature from the input example. Reason: TypeError('The PyTorch flavor does not support List or Dict input types. Please use a pandas.DataFrame or a numpy.ndarray'). To see the full traceback, set the logging level to DEBUG via `logging.getLogger("mlflow").setLevel(logging.DEBUG)`.
# [OK] Exported ONNX to meg2ang.onnx
# 2025/11/25 15:07:10 WARNING mlflow.utils.requirements_utils: Found torch version (2.4.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torch==2.4.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2025/11/25 15:08:28 WARNING mlflow.utils.requirements_utils: Found torchvision version (0.19.1+cu121) contains a local version label (+cu121). MLflow logged a pip requirement for this package as 'torchvision==0.19.1' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2025/11/25 15:08:28 WARNING mlflow.models.model: Failed to validate serving input example {
#   "inputs": {
#     "Npho4760": [
#       [
#         .... Alternatively, you can avoid passing input example and pass model signature instead when logging the model. To ensure the input example is valid prior to serving, please try calling `mlflow.models.validate_serving_input` on the model uri and serving input example. A serving input example can be generated from model input example using `mlflow.models.convert_input_example_to_serving_input` function.
# Got error: The PyTorch flavor does not support List or Dict input types. Please use a pandas.DataFrame or a numpy.ndarray
